# %%
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
import matplotlib.gridspec as gridspec
import re


os.system('cls')

#Leo los datos del archivo '.csv', los datos estan separados por ';', la fila N°1 son los titulos y no se crea la columna index

#modelo = pd.read_csv('D:/EQUIPOS/CCD2/02-MOLDES TALLER/Reglas Iba/Termografico Molde/Modelo_MMS.csv',
modelo = pd.read_csv('C:/Users/Danilo/Desktop/Python/boton/Modelo_MMS_1.csv',

            sep=',',

            header=1,

            index_col=False)


df=pd.DataFrame(modelo)

# %%
df
# Out:
#                            time  SENSOR_TC_Temperature01  \
# 0    30.04.2021 12:13:19.215407                    111.9
# 1    30.04.2021 12:13:19.465407                    111.9
# 2    30.04.2021 12:13:19.715407                    111.9
# 3    30.04.2021 12:13:19.965407                    111.9
# 4    30.04.2021 12:13:20.215407                    111.9
# ..                          ...                      ...
# 527  30.04.2021 12:15:30.965407                    108.3
# 528  30.04.2021 12:15:31.215407                    108.3
# 529  30.04.2021 12:15:31.465407                    108.2
# 530  30.04.2021 12:15:31.715407                    108.2
# 531  30.04.2021 12:15:31.965407                    108.2
#
#      SENSOR_TC_Temperature02  SENSOR_TC_Temperature03  \
# 0                      123.2                    121.0
# 1                      123.3                    121.0
# 2                      123.3                    121.0
# 3                      123.3                    120.9
# 4                      123.4                    120.8
# ..                       ...                      ...
# 527                    121.8                    118.3
# 528                    121.8                    118.3
# 529                    121.7                    118.2
# 530                    121.7                    118.2
# 531                    121.7                    118.2
#
#      SENSOR_TC_Temperature04  SENSOR_TC_Temperature05  \
# 0                      124.1                    128.7
# 1                      124.1                    128.7
# 2                      124.1                    128.7
# 3                      124.1                    128.7
# 4                      124.1                    128.7
# ..                       ...                      ...
# 527                    125.0                    127.6
# 528                    125.0                    127.6
# 529                    125.0                    127.7
# 530                    124.9                    127.7
# 531                    124.9                    127.8
#
#      SENSOR_TC_Temperature06  SENSOR_TC_Temperature07  \
# 0                      113.6                    126.8
# 1                      113.6                    126.8
# 2                      113.6                    126.8
# 3                      113.7                    126.6
# 4                      113.7                    126.6
# ..                       ...                      ...
# 527                    115.1                    127.7
# 528                    115.1                    127.7
# 529                    115.1                    127.7
# 530                    115.0                    127.7
# 531                    115.0                    127.7
#
#      SENSOR_TC_Temperature08  SENSOR_TC_Temperature09  ...  \
# 0                      119.6                    127.7  ...
# 1                      119.6                    127.7  ...
# 2                      119.6                    127.7  ...
# 3                      119.6                    127.6  ...
# 4                      119.7                    127.7  ...
# ..                       ...                      ...  ...
# 527                    121.7                    127.1  ...
# 528                    121.7                    127.1  ...
# 529                    121.8                    127.2  ...
# 530                    121.8                    127.2  ...
# 531                    121.8                    127.1  ...
#
#      SENSOR_TC_Temperature66  SENSOR_TC_Temperature67  \
# 0                      102.7                     96.1
# 1                      102.7                     96.1
# 2                      102.7                     96.1
# 3                      102.7                     96.1
# 4                      102.8                     96.1
# ..                       ...                      ...
# 527                    103.7                     94.5
# 528                    103.7                     94.5
# 529                    103.7                     94.5
# 530                    103.7                     94.5
# 531                    103.6                     94.5
#
#      SENSOR_TC_Temperature68  SENSOR_TC_Temperature69  \
# 0                       99.3                     96.1
# 1                       99.3                     96.1
# 2                       99.3                     96.1
# 3                       99.3                     96.1
# 4                       99.3                     96.1
# ..                       ...                      ...
# 527                     98.8                     94.1
# 528                     98.8                     94.1
# 529                     98.8                     94.1
# 530                     98.8                     94.1
# 531                     98.9                     94.1
#
#      SENSOR_TC_Temperature70  SENSOR_TC_Temperature71  \
# 0                       99.1                    106.5
# 1                       99.1                    106.5
# 2                       99.1                    106.5
# 3                       99.1                    106.5
# 4                       99.2                    106.5
# ..                       ...                      ...
# 527                     98.5                    105.5
# 528                     98.5                    105.5
# 529                     98.4                    105.5
# 530                     98.4                    105.5
# 531                     98.5                    105.5
#
#      SENSOR_TC_Temperature72  L1_ActCastSpeed  L1_SelMouldID  \
# 0                      102.5              0.9              6
# 1                      102.5              0.9              6
# 2                      102.5              0.9              6
# 3                      102.3              0.9              6
# 4                      102.1              0.9              6
# ..                       ...              ...            ...
# 527                    107.0              0.9              6
# 528                    107.0              0.9              6
# 529                    107.0              0.9              6
# 530                    107.0              0.9              6
# 531                    107.0              0.9              6
#
#      L1_ActMouldWidthBOC
# 0                1772.02
# 1                1772.02
# 2                1772.02
# 3                1772.02
# 4                1772.02
# ..                   ...
# 527              1772.02
# 528              1772.02
# 529              1772.02
# 530              1772.02
# 531              1772.02
#
# [532 rows x 76 columns]

# %%
#////////////////////////////Cambio de las cabeseras////////////////////////////


titulos= ['fecha','tc01','tc02','tc03','tc04','tc05','tc06',
        'tc07','tc08','tc09','tc10','tc11','tc12','tc13','tc14','tc15','tc16','tc17','tc18','tc19',
        'tc20','tc21','tc22','tc23','tc24','tc25','tc26','tc27','tc28','tc29','tc30','tc31','tc32',
        'tc33','tc34','tc35','tc36','tc37','tc38','tc39','tc40','tc41','tc42','tc43','tc44','tc45',
        'tc46','tc47','tc48','tc49','tc50','tc51','tc52','tc53','tc54','tc55','tc56','tc57','tc58',
        'tc59','tc60','tc61','tc62','tc63','tc64','tc65','tc66','tc67','tc68','tc69','tc70','tc71',
        'tc72','velocidad','num_molde','ancho']
 

df.columns=titulos


#////////////////////////////Temperaturas por Placas////////////////////////////


lat_izq = np.array(df[['tc01','tc02',
                       'tc25','tc26',
                       'tc49','tc50']], np.float64)


lat_der = np.array(df[['tc13','tc14',
                       'tc37','tc38',
                       'tc61','tc62']], np.float64)

 
ancha_movil = np.array(df[['tc03','tc04','tc05','tc06','tc07','tc08','tc09','tc10','tc11','tc12',
                           'tc27','tc28','tc29','tc30','tc31','tc32','tc33','tc34','tc35','tc36',
                           'tc51','tc52','tc53','tc54','tc55','tc56','tc57','tc58','tc59','tc60']], np.float64)#corregir la 57

 
ancha_fija = np.array(df[['tc15','tc16','tc17','tc18','tc19','tc20','tc21','tc22','tc23','tc24',
                          'tc39','tc40','tc41','tc42','tc43','tc44','tc45','tc46','tc47','tc48',
                          'tc63','tc64','tc65','tc66','tc67','tc68','tc69','tc70','tc71','tc72']],np.float64)



vel_linea = np.array(df[['velocidad']],np.float64)

#ancho_linea = np.array(df[['ancho']],np.float64)


os.system('cls')


def conversion_ancha(placa,row):
    
    fila1=[]
    for j in range(20,30):
        fila1.append(placa[row][j])

    fila2=[]
    for j in range(10,20):
        fila2.append(placa[row][j])

    fila3=[]
    for j in range(0,10):
        fila3.append(placa[row][j])


    nuevo=np.array(np.atleast_1d(fila1,fila2,fila3)).reshape(3,10)
    
    #nuevo=np.random.rand(3,10)
    
    return nuevo


def conversion_angosta(placa,row):
    
    fila1=[]
    for j in range(4,6):
        fila1.append(placa[row][j])

    fila2=[]
    for j in range(2,4):
        fila2.append(placa[row][j])

    fila3=[]
    for j in range(0,2):
        fila3.append(placa[row][j])


    nuevo=np.array(np.atleast_1d(fila1,fila2,fila3)).reshape(3,2)
    
    #nuevo=np.random.rand(3,2)
    
    return nuevo


def promedio(placa_s,placa_temp,fila,row):

    temparaturas=conversion_ancha(placa_temp,row)

    valores_ok=[]

    for j in range(0,10): #recorro las columnas
        if placa_s[fila][j]==1:
            valores_ok.append(temparaturas[fila][j])
    
    valor_promedio=sum(valores_ok)/len(valores_ok)

    return valor_promedio

#print(promedio(status_ancha_movil,ancha_movil,0,0))


'''
def velocidad(row):
    
    fila1=[]
    for j in range(0,1):
        fila1.append(vel_linea[0][j])
    nuevo=np.array(np.atleast_1d(fila1)).reshape(1,1)
    print(nuevo)

    return nuevo
'''


#///////////////////////////////////////////////////////////////////////////////
#
#                                   Interpolacion
#
#///////////////////////////////////////////////////////////////////////////////



def scalematrix(m, scale=10):
  # Crear matriz con ceros del tamaño apropiado
  r = np.zeros(((m.shape[0]-1)*scale+1, (m.shape[1]-1)*scale+1))

  # Rellenar filas multiplo de scale (interpolando entre valores de los elementos de la fila)
  for fil in range(m.shape[0]):
    for col in range(m.shape[1]-1):
      r[fil*scale, col*scale:(col+1)*scale+1] = np.linspace(m[fil,col], m[fil,col+1], scale+1)

  # Rellenar resto de ceros, interpolando entre elementos de las columnas
  for fil in range(m.shape[0]-1):
    for col in range(r.shape[1]):
      r[fil*scale:(fil+1)*scale + 1, col] = np.linspace(r[fil*scale,col], r[(fil+1)*scale, col], scale+1)
  return r


#////////////////////////////GRAFICOS////////////////////////////



def _annotate(ax, x, y, title):
    # this all gets repeated below:
    #X, Y = np.meshgrid(x, y)
    #ax.plot(X.flat, Y.flat, '+', color='m')
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(y.min(), y.max())
    ax.set_title(title)

#///////////////////////////////////////////////////////////////////////////////
#
#                                   ANIMACION
#
#///////////////////////////////////////////////////////////////////////////////

#Para Placas Anchas
nrows = 21#3
ncols = 91#10
x = np.arange(ncols + 1)
y = np.arange(nrows + 1)

#Para Placas Angostas
nrows2 = 21#3
ncols2 = 11#2
x2 = np.arange(ncols2 + 1)
y2 = np.arange(nrows2 + 1)

#////////////////////////////////////////////////////////////////////////////////

fig = plt.figure(figsize=(10, 7))       #Tamaño de la ventana
gs = gridspec.GridSpec(3, 6, wspace=0.1, hspace=0.4)            #Es para dibujar graficos(3 filas x 6 columnas)

#-------------------------------------------------------------------------------

ax = plt.subplot(gs[1,0:5])
ax.set_axis_off()
Z=scalematrix(conversion_ancha(ancha_movil,2), scale=10)#conversion_ancha(ancha_movil,1)
cmap = mpl.cm.jet
#bounds = [0,20,80,100,120,150,160]
#norm = mpl.colors.BoundaryNorm(bounds, cmap.N, extend='both')
quad1 = ax.pcolormesh(x, y, Z, cmap=cmap, shading='auto',vmin=20, vmax=250)#vmin=Z.min(), vmax=Z.max())
contour1 = ax.contour(Z)
cb1 = fig.colorbar(quad1, ax=ax)





#-------------------------------------------------------------------------------

ax2 = plt.subplot(gs[0,0:5])
ax2.set_axis_off()
Z2=scalematrix(conversion_ancha(ancha_fija,2), scale=10)#conversion_ancha(ancha_fija,1)
quad2 = ax2.pcolormesh(x, y, Z2, cmap=cmap, shading='auto',vmin=20, vmax=250)#vmin=Z2.min(), vmax=Z2.max())
contour2 = ax2.contour(Z2)
cb2 = fig.colorbar(quad2, ax=ax2)


#-------------------------------------------------------------------------------

ax3 = plt.subplot(gs[0,5:])
ax3.set_axis_off()
Z3=scalematrix(conversion_angosta(lat_der,2), scale=10)#conversion_angosta(lat_der,2)
quad3 = ax3.pcolormesh(x2, y2, Z3, cmap=cmap, shading='auto',vmin=20, vmax=250)#vmin=Z3.min(), vmax=Z3.max())
contour3 = ax3.contour(Z3)
cb3 = fig.colorbar(quad3, ax=ax3)

#-------------------------------------------------------------------------------

ax4 = plt.subplot(gs[1,5:])
ax4.set_axis_off()
Z4=scalematrix(conversion_angosta(lat_izq,2), scale=10)#conversion_angosta(lat_izq,2)
quad4 = ax4.pcolormesh(x2, y2, Z4, cmap=cmap, shading='auto',vmin=20, vmax=250)#vmin=Z4.min(), vmax=Z4.max())
contour4 = ax4.contour(Z4)
cb4 = fig.colorbar(quad4, ax=ax4)

#-------------------------------------------------------------------------------

#t=np.linspace(0.0, int(vel_linea.size/(nrows2*ncols2)), num=int(vel_linea.size/(nrows2*ncols2)))#esta instrucion la puedo usar como indice
#v=np.linspace(0.0, 2.0, num=int(vel_linea.size/(nrows2*ncols2)))

ax5 = plt.subplot(gs[2,:])
xdata, ydata = [], []
line2, = ax5.plot(1,vel_linea[1],'b',linewidth=2)

#-------------------------------------------------------------------------------



def init():
    _annotate(ax, x, y, "Ancha Movil")
    _annotate(ax2, x, y, "Ancha fija")
    _annotate(ax3, x2, y2, "Lateral Derecha")
    _annotate(ax4, x2, y2, "Lateral Izquierda")
    
    line2.set_data([],[])
    ax5.set_xlim(0,vel_linea.size-1)
    ax5.set_ylim(-0.3,2)
    ax5.set_title('Velocidad')

def update(row):
    
    Z=scalematrix(conversion_ancha(ancha_movil,row), scale=10)#conversion_ancha(ancha_fija,row)
    quad1.set_array(Z.ravel())
    global contour1
    for c in contour1.collections:
        c.remove()
    contour1 = ax.contour(Z)

    #-------------------------------------------------------------------------------------------
    Z2=scalematrix(conversion_ancha(ancha_fija,row), scale=10)#conversion_ancha(ancha_movil,row)
    quad2.set_array(Z2.ravel())
    global contour2
    for c in contour2.collections:
        c.remove()
    contour2 = ax2.contour(Z2)

    #-------------------------------------------------------------------------------------------

    Z3=scalematrix(conversion_angosta(lat_der,row), scale=10)#conversion_angosta(lat_der,row)
    quad3.set_array(Z3.ravel())
    global contour3
    for c in contour3.collections:
        c.remove()
    contour3 = ax3.contour(Z3)

    #-------------------------------------------------------------------------------------------

    Z4=scalematrix(conversion_angosta(lat_izq,row), scale=10)#conversion_angosta(lat_izq,row)
    quad4.set_array(Z4.ravel())
    global contour4
    for c in contour4.collections:
        c.remove()
    contour4 = ax4.contour(Z4)

    #-------------------------------------------------------------------------------------------

    xdata.append(row)
    ydata.append(vel_linea[row])
    line2.set_data(xdata, ydata)

    return quad1,quad2,quad3,quad4,line2,contour1,contour2,contour3,contour4


    
#///////////////////////////////////////////////////////////////////////////////

num_celdas = vel_linea.size-1
ani = FuncAnimation(fig, update, frames=num_celdas, init_func=init, repeat= False, blit=False)
plt.show()

#///////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# # Temperaturas en la Placa Fija

# %%
global contour1
#Para Placas Anchas
nrows = 21#3
ncols = 91#10
x = np.arange(ncols + 1)
y = np.arange(nrows + 1)

celda = 0


#////////////////////////////////////////////////////////////////////////////////

fig = plt.figure(figsize=(20, 10))       #Tamaño de la ventana
#gs = gridspec.GridSpec(2, 1, wspace=0.1, hspace=0.4)            #Es para dibujar graficos(3 filas x 6 columnas)

#-------------------------------------------------------------------------------

ax = plt.subplot()
ax.set_axis_off()
Z=scalematrix(conversion_ancha(ancha_movil,celda), scale=10)#conversion_ancha(ancha_movil,1)
cmap = mpl.cm.jet
#bounds = [0,20,80,100,120,150,160]
#norm = mpl.colors.BoundaryNorm(bounds, cmap.N, extend='both')
quad1 = ax.pcolormesh(x, y, Z, cmap=cmap, shading='auto',vmin=60, vmax=160)#vmin=Z.min(), vmax=Z.max())
contour1 = ax.contour(Z)
cb1 = fig.colorbar(quad1, ax=ax)



Z=scalematrix(conversion_ancha(ancha_movil,celda), scale=10)#conversion_ancha(ancha_fija,row)
quad1.set_array(Z.ravel())
#global contour1
for c in contour1.collections:
    c.remove()
contour1 = ax.contour(Z)

##############################################################################################

# Loop over data dimensions and create text annotations.
c=0
for i in range(0,10):
    for j in range(0,3):
        c=c+1
        text = ax.text(i*9+5, j*7+4, conversion_ancha(ancha_movil,celda)[j][i].round(2) ,ha="center", va="center", color="b",fontsize = 15)

##############################################################################################


#-------------------------------------------------------------------------------
'''
###############################################################################################################

ax2 = plt.subplot(gs[0,0:5])
ax2.set_axis_off()
Z2=scalematrix(conversion_ancha(ancha_fija,2), scale=10)#conversion_ancha(ancha_fija,1)
quad2 = ax2.pcolormesh(x, y, Z2, cmap=cmap, shading='auto',vmin=60, vmax=160)#vmin=Z2.min(), vmax=Z2.max())
contour2 = ax2.contour(Z2)
cb2 = fig.colorbar(quad2, ax=ax2)


    
Z2=scalematrix(conversion_ancha(ancha_fija,celda), scale=10)#conversion_ancha(ancha_fija,row)
quad2.set_array(Z2.ravel())
global contour2
for c in contour2.collections:
        c.remove()
contour2 = ax2.contour(Z2)

####################################################################################################################
'''

######## Encabezado de Imagen ########

print(f' -------------------\n| Placa Ancha Movil |\n -------------------')

plt.show()

######## Pie de Imagen ######## 

datos = df['fecha'][celda],  df['velocidad'][celda], df['num_molde'][celda], df['ancho'][celda]

#datos = list(datos)

print(f'Fecha: {datos[0][:10]}\nHora: {datos[0][11:19]}\nVelocidad: {datos[1]} m/min\nMolde: {datos[2]}\nAncho: {datos[3]}')
# Out:
#  -------------------
# | Placa Ancha Movil |
#  -------------------
# Fecha: 30.04.2021
# Hora: 12:13:19
# Velocidad: 0.9 m/min
# Molde: 6
# Ancho: 1772.02
